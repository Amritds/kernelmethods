# %%
from __future__ import division
import numpy as np
import math
import matplotlib.mlab as mlab
import kernelClassifier as kC
#reload(kC) 
from sklearn import linear_model, model_selection
import matplotlib.pyplot as plt
import sys, os 
from scipy.stats import norm
#Random seed.
np.random.seed(432)

# %%
############################ Code generic to all data models: ########################################################

#Calculates the desired ratio for observed data, given mu value via ratio estimation.
def calc_ratio(X_class1, X_class2, obsData,kernel,figname,clf):
    y_vals_class1 = np.zeros((len(X_class1),1))+1
    y_vals_class2 = np.zeros((len(X_class2),1))-1

    y_vals = np.vstack([y_vals_class1,y_vals_class2])
    X_vals = np.vstack([X_class1,X_class2])

    datapoints=np.hstack([X_vals,y_vals])
    np.random.shuffle(datapoints)

    X_vals=datapoints[:,0:datapoints.shape[1]-1]
    y_vals=datapoints[:,datapoints.shape[1]-1]

    #Learn best weights for classification and get the log_ratio wrt observed data.
    log_ratio=classify(X_vals,y_vals,kernel,figname,clf).activation(obsData)

    #Calculate ratio.
    ratio=np.exp(np.clip(log_ratio,-500,500))
    
    return ratio


def classify(X_vals,y_vals,kernel,figname,clf):
    X_train,X_test,y_train,y_test = model_selection.train_test_split(X_vals,y_vals,test_size=0.30)
    
    Cs = np.array([0,1e-7,1e-5,1e-3,1e-1,1])
   # Cs =np.array([0])
    
    bestScore = 0
    chosen_C= -1

    kf = model_selection.KFold(n_splits=5)
    #Choose a regularization parameter.
    for c in Cs:
        print("Training for c value: ",c)
        sum = 0
        for train, test in kf.split(X_vals):
            clf.train(X_vals[train],y_vals[train],c)
            sum += clf.score(X_vals[test],y_vals[test])
        average = sum/5
        plt.plot(c,average,'b*')
        if(chosen_C==-1 or bestScore < average):
            chosen_C= c
            bestScore = average
        
    fig=plt.figure()        
    plt.plot(chosen_C,bestScore,'r+')
    fig.savefig('./figures/'+figname+'.pdf')
    clf.train(X_vals,y_vals,chosen_C)
    print("Chosen c value: ",chosen_C)
    print("Classification accuracy: ",bestScore)
    return clf   


def estimateProbabilities(observed_data, prior, theta_values, generator_marginal, generator_thetaGiven, create_basis, n_samples, clf,kernel=kC.kernelLinear):
    #Observed data.
    observed_data_basis=create_basis(observed_data)
    
    #Sample from the marginal.
    marginal_samples=generator_marginal(n_samples)
    marginal_samples_basis=create_basis(marginal_samples)

    probabilities=[]
    for th in theta_values:
        print("-----------CALCULATING Theta VALUE : ",th," -------------------")
        #Sample from the given class.
        theta_samples=generator_thetaGiven(th,n_samples)
        theta_samples_basis=create_basis(theta_samples)
    
        prob= prior*calc_ratio(theta_samples_basis,marginal_samples_basis, observed_data_basis, kernel,str(th)+'_crossValidation',clf)
        probabilities.append(np.asscalar(prob))
    return np.array(probabilities)
##########################################################################################################################

# %% [markdown]
# ### GAUSSIAN TOY EXAMPLE ###

# %%
#Takes a single value x and returns a b dimensional basis vector [1,x,x^2,...x^b]
def create_basis(msamp,b=3):
    basis=np.ones((len(msamp),1))
    for i in range (1,b):
        temp=np.power(msamp,i)
        basis=np.hstack([basis,temp])
    return basis

#Generates n 1-D samples from a gaussian ditribution with given mean.
def generator_thetaGiven(mu,n_samples):
    X = np.random.normal(mu,3,(n_samples,1))
    return X

#Generates n 1-D samples from gaussian ditributions, assuming a uniform dist. over means between [-5,5]
def generator_marginal(n_samples):
    mu= np.random.uniform(-20,20,(n_samples,1));
    X = np.random.normal(mu,3,(n_samples,1));
    return X

# %% [markdown]
# #### Linear Kernel experiments ####

# %% [markdown]
# ##### Without scaling, without change in basis #####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data=np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
clf=kC.KernelClassifier(kC.kernelLinear,withScaling=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, create_basis, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3b3bc8d8d1d2> in <module>()
#      17
#      18 #Uses linear kernel by default -can specify custom kernel.
# ---> 19 clf=kC.KernelClassifier(kC.kernelLinear,withScaling=False,withPCA=False)
#      20 probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, create_basis, n_samples,clf)
#      21
#
# TypeError: __init__() got an unexpected keyword argument 'withPCA'

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()

# %% [markdown]
# ##### With scaling only #####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data = np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
clf=kC.KernelClassifier(kC.kernelLinear,withPCA=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, create_basis, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.184 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.803 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.298 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.201 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.175 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.178 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.812 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.288 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.171 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.189 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.174 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.304 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.174 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.201 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.159 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.809 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.279 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.169 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.149 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.180 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.762 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.340 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.175 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.194 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.276 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.740 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.179 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.191 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.224 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.897 seconds
# ('Chosen c value: ', 1.0)
# ('Classification accuracy: ', 0.8265)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.001 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.945 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.004 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.787 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.958 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.989 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.945 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.018 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.812 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.949 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.043 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.958 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.029 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.803 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.951 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.043 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.961 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.005 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.780 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.955 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.011 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.952 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.014 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.844 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.896 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.001 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.968 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.003 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.842 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.991 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.977 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8305)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.238 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.192 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.187 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.258 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.180 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.257 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.212 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.287 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.185 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.242 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.160 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.167 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.210 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.266 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.205 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.187 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.219 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.184 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.237 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 2.196 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.178 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.259 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.166 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.258 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.213 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.155 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.271 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.215 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.900 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8300000000000001)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.945 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.964 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.022 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.052 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.956 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.958 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.974 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.016 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.085 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.985 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.962 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.963 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.022 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.074 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.984 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.986 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.967 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.014 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.063 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.964 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.974 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.990 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.998 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.076 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.959 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.924 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.957 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.996 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.065 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.942 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.797 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8265)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.388 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.072 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.123 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.671 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.094 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.377 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.062 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.090 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.627 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.056 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.371 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.054 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.137 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.632 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.037 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.384 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.059 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.088 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.644 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.056 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.379 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.042 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.095 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.049 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.427 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.060 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.086 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.646 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.112 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.601 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8365)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.961 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.576 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.223 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.442 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.802 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.939 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.581 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.234 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.412 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.795 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.039 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 1.583 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.214 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.421 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.799 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.964 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.588 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.216 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.437 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.805 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.967 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.591 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.210 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.374 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.584 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.856 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.593 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.202 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.519 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.575 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.705 seconds
# ('Chosen c value: ', 1.0)
# ('Classification accuracy: ', 0.8404999999999999)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.083 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.106 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.115 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.857 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.980 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.097 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.121 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.123 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.868 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.973 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.066 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.138 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.133 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.855 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.970 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.099 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.136 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.124 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.864 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.970 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.081 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.118 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.122 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.862 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.961 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.010 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.109 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.108 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.920 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.956 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.902 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8320000000000001)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.260 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.308 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.249 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.175 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.244 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.222 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.334 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.265 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.184 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.287 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.196 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.288 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.260 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.140 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.274 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.217 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.313 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.250 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.143 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.289 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.235 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.347 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.248 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.213 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.257 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.204 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.308 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.273 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.148 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.306 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.981 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8425)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.055 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 2.127 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.739 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.047 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.914 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.055 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.141 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.758 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.961 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.922 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.074 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.134 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.765 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.955 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.899 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.076 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.113 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.775 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.977 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.923 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.070 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.136 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.811 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.969 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.934 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.066 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.140 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.701 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.969 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.908 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.014 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8414999999999999)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.330 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.384 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.828 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.167 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.720 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.319 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.380 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.826 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.147 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.713 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.309 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.381 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.814 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.150 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.712 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.323 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.363 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.826 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.156 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.709 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.308 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.367 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.817 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.152 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.720 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.339 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.375 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.763 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.091 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.709 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.057 seconds
# ('Chosen c value: ', 1.0)
# ('Classification accuracy: ', 0.8345)

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()

# %% [markdown]
# ##### Change in basis only #####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data = np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
clf=kC.KernelClassifier(kC.kernelLinear,withScaling=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, create_basis, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.675 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.579 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.402 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.186 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.424 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.762 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.373 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.140 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.079 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.132 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.434 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.596 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.435 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.174 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.148 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.592 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.503 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.139 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.158 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.249 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.437 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.417 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.216 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.098 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.365 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.716 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.505 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.255 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.087 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.138 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.888 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.837)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.483 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.522 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.561 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.754 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.751 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.457 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.547 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.417 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.581 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.588 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.475 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.484 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.498 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.695 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.660 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.462 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.720 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.437 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.529 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.645 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.486 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.712 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.587 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.645 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.573 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.553 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.645 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.502 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.600 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.606 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.515 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8310000000000001)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.684 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.253 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.216 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.695 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.574 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.289 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.208 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.534 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.684 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.607 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.243 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.455 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.240 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.780 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.597 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.313 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.675 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 2.685 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.267 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.341 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.753 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.664 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.270 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.408 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.311 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.808 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.471 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8185)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.071 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.223 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.342 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.156 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.190 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.050 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.917 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.078 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.912 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.120 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.862 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.932 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.037 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.905 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.891 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.027 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.861 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.018 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.917 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.974 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.186 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.089 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.146 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.023 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.021 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.225 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.054 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.195 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.143 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.270 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.685 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8285)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.934 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.505 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.522 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.905 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.641 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.493 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.535 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.516 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.437 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.076 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.499 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.379 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.618 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.171 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.624 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.477 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.429 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.264 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.963 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.396 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.432 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.630 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.502 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.414 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.486 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.988 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.398 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.058 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.258 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8205)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.319 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.608 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.466 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.370 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.250 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.434 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.546 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.563 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.734 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.446 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.469 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.866 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.595 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.628 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.526 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.842 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.431 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.568 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.514 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.488 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.583 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.545 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.476 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.749 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.161 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.916 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.547 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.378 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.102 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8184999999999999)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.521 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.350 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.195 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.281 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.135 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.532 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.144 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.064 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.982 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.953 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.576 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.138 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.198 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.943 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.962 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.381 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.119 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.096 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.971 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.963 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.385 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.090 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.097 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.948 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.947 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.380 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.125 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.101 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.959 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.952 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.638 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8290000000000001)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.991 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.001 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.908 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.427 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.214 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.080 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.075 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.004 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.525 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.234 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.094 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.127 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.026 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.543 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.244 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.147 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.175 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.085 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.550 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.303 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.105 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.133 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.026 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.455 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.261 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.186 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.006 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.940 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.489 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.248 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.519 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8275)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.535 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.718 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.322 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.462 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.529 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.576 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.524 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.351 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.498 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.584 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.529 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.484 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.367 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.496 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.586 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.520 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.540 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.377 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.484 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.576 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.504 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.550 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.399 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.610 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.551 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.665 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.491 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.539 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.676 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.341 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8274999999999999)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.853 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.140 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.569 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.157 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.357 seconds
# ('Training for c value: ', 9.9999999999999995e-08)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.650 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 4.011 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.510 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.869 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.289 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.494 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.526 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.700 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.221 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.463 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.719 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.383 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.836 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.431 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.544 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.851 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.615 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.713 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.344 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.556 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.827 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.457 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.889 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.385 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.406 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8355)

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()
