# %%
from __future__ import division
import numpy as np
import math
import matplotlib.mlab as mlab
import kernelClassifier as kC
reload(kC) 
from sklearn import linear_model, model_selection
import matplotlib.pyplot as plt
import sys, os 
from scipy.stats import norm
#Random seed.
np.random.seed(432)

# %%
############################ Code generic to all data models: ########################################################

#Calculates the desired ratio for observed data, given mu value via ratio estimation.
def calc_ratio(X_class1, X_class2, obsData,kernel,figname,clf):
    y_vals_class1 = np.zeros((len(X_class1),1))+1
    y_vals_class2 = np.zeros((len(X_class2),1))-1

    y_vals = np.vstack([y_vals_class1,y_vals_class2])
    X_vals = np.vstack([X_class1,X_class2])

    datapoints=np.hstack([X_vals,y_vals])
    np.random.shuffle(datapoints)

    X_vals=datapoints[:,0:datapoints.shape[1]-1]
    y_vals=datapoints[:,datapoints.shape[1]-1]

    #Learn best weights for classification and get the log_ratio wrt observed data.
    log_ratio=classify(X_vals,y_vals,kernel,figname,clf).activation(obsData)

    #Calculate ratio.
    ratio=np.exp(np.clip(log_ratio,-500,500))
    
    return ratio


def classify(X_vals,y_vals,kernel,figname,clf):
    X_train,X_test,y_train,y_test = model_selection.train_test_split(X_vals,y_vals,test_size=0.30)
    
    Cs = np.array([0,1e-15,1e-13])
   # Cs =np.array([0])
    
    bestScore = 0
    chosen_C= -1

    kf = model_selection.KFold(n_splits=5)
    #Choose a regularization parameter.
    for c in Cs:
        print("Training for c value: ",c)
        sum = 0
        for train, test in kf.split(X_vals):
            clf.train(X_vals[train],y_vals[train],c)
            sum += clf.score(X_vals[test],y_vals[test])
        average = sum/5
        plt.plot(c,average,'b*')
        if(chosen_C==-1 or bestScore < average):
            chosen_C= c
            bestScore = average
        
    fig=plt.figure()        
    plt.plot(chosen_C,bestScore,'r+')
    fig.savefig('./figures/'+figname+'.pdf')
    clf.train(X_vals,y_vals,chosen_C)
    print("Chosen c value: ",chosen_C)
    print("Classification accuracy: ",bestScore)
    return clf   


def estimateProbabilities(observed_data, prior, theta_values, generator_marginal, generator_thetaGiven,n_samples, clf,kernel=kC.kernelLinear):
    #Sample from the marginal.
    marginal_samples=generator_marginal(n_samples)

    probabilities=[]
    for th in theta_values:
        print("-----------CALCULATING Theta VALUE : ",th," -------------------")
        #Sample from the given class.
        theta_samples=generator_thetaGiven(th,n_samples)
    
        prob= prior*calc_ratio(theta_samples,marginal_samples, observed_data, kernel,str(th)+'_crossValidation',clf)
        probabilities.append(np.asscalar(prob))
    return np.array(probabilities)
##########################################################################################################################

# %% [markdown]
# ### GAUSSIAN TOY EXAMPLE ###

# %%
#Generates n 1-D samples from a gaussian ditribution with given mean.
def generator_thetaGiven(mu,n_samples):
    X = np.random.normal(mu,3,(n_samples,1))
    return X

#Generates n 1-D samples from gaussian ditributions, assuming a uniform dist. over means between [-5,5]
def generator_marginal(n_samples):
    mu= np.random.uniform(-20,20,(n_samples,1));
    X = np.random.normal(mu,3,(n_samples,1));
    return X

# %% [markdown]
# #### Polynomial Kernel degree 2 -Scaled ####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data=np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
kPoly =lambda X1,X2: kC.kernelPoly(X1,X2,2)
clf=kC.KernelClassifier(kPoly,withPCA=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.055 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.284 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.310 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.341 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.200 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.028 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.235 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.314 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.345 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.176 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.027 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.179 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.312 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.347 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.223 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.017 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.219 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.295 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.424 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.318 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.037 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.315 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.450 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.236 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.183 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.079 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.124 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.234 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.144 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.004 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.098 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.058 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.011 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.003 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.440 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.541 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.390 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.555 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.376 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.674 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8405000000000001)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.003 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.081 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.251 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.177 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.218 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.978 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.098 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.436 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.311 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.249 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.969 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.085 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.222 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.190 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.234 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.987 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.069 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.241 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.216 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.131 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.795 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.134 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.218 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.381 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.312 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.014 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.187 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.177 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.230 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.249 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.487 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.812 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.536 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.444 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.909 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.673 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.295 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.524 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.300 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.629 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.131 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8345)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.203 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 2.275 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.090 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.282 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.124 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.102 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.105 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.026 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.084 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.118 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.089 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.110 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.973 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.121 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.105 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.142 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.121 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.115 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.082 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.132 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.092 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.129 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.118 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.123 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.098 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.199 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.330 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.200 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.172 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.217 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.029 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.063 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.916 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.005 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.176 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.745 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.532 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.657 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.680 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.742 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.206 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.828)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.584 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.702 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.993 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.710 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.992 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.592 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.688 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.004 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.686 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.993 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.578 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.781 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.113 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.737 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.002 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.730 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.125 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.769 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.094 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.682 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.768 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.049 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.726 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.057 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.775 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.816 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.109 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.670 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.888 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.937 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.521 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.824 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.211 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.524 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.606 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.595 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.630 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.776 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.712 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.298 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8295)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.905 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.022 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.787 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.067 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 2.116 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.755 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.938 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.810 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.083 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.998 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.780 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.002 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.763 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.103 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.983 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.791 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.937 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.795 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.083 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.979 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.676 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.995 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.754 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.171 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.038 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.884 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.648 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.969 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.921 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.894 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.315 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.703 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.764 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.847 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.929 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.646 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.686 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.601 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.762 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.300 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.523 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8205)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.948 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.318 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.999 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.042 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.945 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.910 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.202 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.945 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.968 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.917 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.934 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.269 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.895 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.976 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.873 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.830 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.167 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.893 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.916 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.894 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.861 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.277 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.900 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.031 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.011 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.038 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.912 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.005 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.008 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.889 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.740 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.755 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.547 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.452 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.732 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.670 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.591 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.654 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.660 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.658 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.779 seconds
# ('Chosen c value: ', 1000.0)
# ('Classification accuracy: ', 0.8215)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.697 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.690 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.686 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.651 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.861 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.670 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.601 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 1.597 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.650 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.821 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.697 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.483 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.602 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.633 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.786 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.664 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.481 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.600 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.641 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.786 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.680 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.524 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.529 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.656 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.795 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.702 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.537 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.430 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.816 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.449 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.526 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.645 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.996 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.162 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.476 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.616 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.641 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.633 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.637 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.182 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8295)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.249 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.250 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.266 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.192 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.496 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.261 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.184 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.174 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.128 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.349 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.257 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.222 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.187 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.139 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.359 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.227 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.169 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.184 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.108 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.279 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.234 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.257 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.211 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.144 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.285 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.176 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.203 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.136 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.156 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.207 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.094 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.297 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.197 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.290 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.893 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.830 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.683 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.611 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.747 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.574 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8285)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.847 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.578 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.829 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.817 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.947 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.811 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.554 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.840 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.806 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.939 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 1.799 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.558 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.825 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.889 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.819 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.544 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.870 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.883 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.013 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.964 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.605 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.832 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.857 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.910 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.561 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.528 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.808 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.716 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.972 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.816 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.781 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.884 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.839 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.714 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.346 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.396 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.667 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.411 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.959 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8300000000000001)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.358 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.302 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.188 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.991 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.207 seconds
# ('Training for c value: ', 1.0000000000000001e-05)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.365 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.155 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.126 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.970 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.187 seconds
# ('Training for c value: ', 0.001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.339 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.205 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.179 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.975 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.184 seconds
# ('Training for c value: ', 0.10000000000000001)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.307 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.138 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.110 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.023 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.182 seconds
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.226 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.110 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.178 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.000 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.181 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.075 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.180 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.125 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.993 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.205 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.847 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.127 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.064 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.228 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.960 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.695 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.541 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.488 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.565 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.431 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.099 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.835)

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()

# %% [markdown]
# #### Polynomial Kernel degree 4 - Scaled, with change in basis #####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data=np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
kPoly =lambda X1,X2: kC.kernelPoly(X1,X2,4)
clf=kC.KernelClassifier(kPoly)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.148 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.896 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.109 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.932 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.098 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.148 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.017 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.201 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.887 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.047 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.031 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.816 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.013 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.898 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.895 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.242 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8165000000000001)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.754 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.477 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.554 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.967 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.121 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.659 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.456 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.520 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.910 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.123 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.595 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.449 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.511 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.916 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.134 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.162 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.819)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.702 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.592 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.426 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.508 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.436 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.614 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.620 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.442 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.491 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.443 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.626 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.566 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.410 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.537 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.424 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.731 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8320000000000001)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.625 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.611 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.664 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.653 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.654 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.584 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.642 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.792 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.686 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.641 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.594 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.591 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.640 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.631 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.626 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.565 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.833)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.202 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.073 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.975 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.081 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.021 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.179 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.216 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.089 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.080 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.942 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.158 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.054 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.979 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.094 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.933 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.933 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8385)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.183 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.173 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.224 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.074 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.144 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.146 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.206 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.070 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.142 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.182 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.260 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.785 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.079 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.618 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8305)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.507 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.625 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.470 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.540 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.479 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.474 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.613 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.498 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.550 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.515 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.478 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.490 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.574 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.498 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.806 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.8280000000000001)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.500 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.236 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.502 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.346 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.138 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.417 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.143 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.394 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.383 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.235 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.508 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.075 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.339 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.346 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.215 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.472 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.818)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.475 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.660 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.560 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.471 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.020 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.474 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.540 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.549 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.478 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.017 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.465 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.636 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.576 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.640 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.248 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.643 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.7995)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 0.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.979 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.192 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.844 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.005 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.192 seconds
# ('Training for c value: ', 1.0000000000000001e-15)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.978 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.088 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.690 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.942 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.195 seconds
# ('Training for c value: ', 1e-13)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.942 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.977 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.708 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.003 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.197 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.830 seconds
# ('Chosen c value: ', 0.0)
# ('Classification accuracy: ', 0.783)

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()
