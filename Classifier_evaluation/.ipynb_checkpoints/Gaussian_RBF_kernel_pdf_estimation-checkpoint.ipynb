# %%
from __future__ import division
import numpy as np
import math
import matplotlib.mlab as mlab
import kernelClassifier as kC
reload(kC) 
from sklearn import linear_model, model_selection
import matplotlib.pyplot as plt
import sys, os 
from scipy.stats import norm
#Random seed.
np.random.seed(432)

# %%
############################ Code generic to all data models: ########################################################

#Calculates the desired ratio for observed data, given mu value via ratio estimation.
def calc_ratio(X_class1, X_class2, obsData,kernel,figname,clf):
    y_vals_class1 = np.zeros((len(X_class1),1))+1
    y_vals_class2 = np.zeros((len(X_class2),1))-1

    y_vals = np.vstack([y_vals_class1,y_vals_class2])
    X_vals = np.vstack([X_class1,X_class2])

    datapoints=np.hstack([X_vals,y_vals])
    np.random.shuffle(datapoints)

    X_vals=datapoints[:,0:datapoints.shape[1]-1]
    y_vals=datapoints[:,datapoints.shape[1]-1]

    #Learn best weights for classification and get the log_ratio wrt observed data.
    log_ratio=classify(X_vals,y_vals,kernel,figname,clf).activation(obsData)

    #Calculate ratio.
    ratio=np.exp(np.clip(log_ratio,-500,500))
    
    return ratio


def classify(X_vals,y_vals,kernel,figname,clf):
    X_train,X_test,y_train,y_test = model_selection.train_test_split(X_vals,y_vals,test_size=0.30)
    
    Cs = np.array([1,1e1,1e3,1e5,1e6,1e7,1e9,1e10,1e11,1e12])
   # Cs =np.array([0])
    
    bestScore = 0
    chosen_C= -1

    kf = model_selection.KFold(n_splits=5)
    #Choose a regularization parameter.
    for c in Cs:
        print("Training for c value: ",c)
        sum = 0
        for train, test in kf.split(X_vals):
            clf.train(X_vals[train],y_vals[train],c)
            sum += clf.score(X_vals[test],y_vals[test])
        average = sum/5
        plt.plot(c,average,'b*')
        if(chosen_C==-1 or bestScore < average):
            chosen_C= c
            bestScore = average
        
    fig=plt.figure()        
    plt.plot(chosen_C,bestScore,'r+')
    fig.savefig('./figures/'+figname+'.pdf')
    clf.train(X_vals,y_vals,chosen_C)
    print("Chosen c value: ",chosen_C)
    print("Classification accuracy: ",bestScore)
    return clf   


def estimateProbabilities(observed_data, prior, theta_values, generator_marginal, generator_thetaGiven,n_samples, clf,kernel=kC.kernelLinear):
    #Sample from the marginal.
    marginal_samples=generator_marginal(n_samples)

    probabilities=[]
    for th in theta_values:
        print("-----------CALCULATING Theta VALUE : ",th," -------------------")
        #Sample from the given class.
        theta_samples=generator_thetaGiven(th,n_samples)
    
        prob= prior*calc_ratio(theta_samples,marginal_samples, observed_data, kernel,str(th)+'_crossValidation',clf)
        probabilities.append(np.asscalar(prob))
    return np.array(probabilities)
##########################################################################################################################

# %% [markdown]
# ### GAUSSIAN TOY EXAMPLE ###

# %%
#Generates n 1-D samples from a gaussian ditribution with given mean.
def generator_thetaGiven(mu,n_samples):
    X = np.random.normal(mu,3,(n_samples,1))
    return X

#Generates n 1-D samples from gaussian ditributions, assuming a uniform dist. over means between [-5,5]
def generator_marginal(n_samples):
    mu= np.random.uniform(-20,20,(n_samples,1));
    X = np.random.normal(mu,3,(n_samples,1));
    return X

# %% [markdown]
# #### RBF Kernel width 0.3 -Scaled ####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data=np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
kRBF =lambda X1,X2: kC.kernelRBF(X1,X2,0.3)
clf=kC.KernelClassifier(kRBF,withPCA=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.916 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.869 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.974 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.998 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.859 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.746 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.655 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.764 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.563 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.784 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.526 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.672 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.779 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.909 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.925 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.944 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.856 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.795 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.837 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.895 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.495 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.645 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.698 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.961 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.695 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.853 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.751 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.387 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.238 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.542 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.889 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.716 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.012 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.148 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.890 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.772 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.661 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.650 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.653 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.721 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.414 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.417 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.419 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.419 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.413 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.367 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.378 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.377 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.362 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.405 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.8375)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.989 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.026 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.827 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.004 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.487 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.773 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.763 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.832 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.816 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.798 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.796 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.022 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.008 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.893 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.970 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.716 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.449 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.713 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.768 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.793 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.587 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.590 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.643 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.619 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.572 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.395 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.415 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.494 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.484 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.011 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.024 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.007 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.965 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 0.765 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.654 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.657 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.783 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.653 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.659 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.416 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.416 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.477 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.419 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.419 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.360 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.785 seconds
# ('Chosen c value: ', 100000.0)
# ('Classification accuracy: ', 0.8355)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.524 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.727 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.412 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.549 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.692 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.735 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.580 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.664 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.581 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.874 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.472 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.712 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.754 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.958 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.750 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.742 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.500 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.506 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.442 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.642 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.518 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.425 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.489 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.416 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.574 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.562 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.294 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.543 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.473 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.543 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.008 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.845 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.069 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.851 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.836 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.665 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.653 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.715 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.717 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.720 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.418 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.424 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.474 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.426 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.416 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.362 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.360 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.365 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.358 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.360 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.967 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.8285)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.552 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.794 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.466 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.783 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.648 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.680 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.651 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.632 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.773 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.626 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.673 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.754 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.707 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.701 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.662 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.760 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.428 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.669 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.639 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.432 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.600 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.610 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.353 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.476 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.282 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.790 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.435 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.411 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.575 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.956 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.979 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.070 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.036 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.951 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.672 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.596 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.658 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.661 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.676 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.480 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.473 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.483 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.419 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.365 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.364 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.416 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.364 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.955 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.827)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.748 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.714 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.461 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.975 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.653 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.705 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.725 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.558 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.432 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.596 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.680 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.886 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.592 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.636 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.560 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.860 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.504 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.494 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.740 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.366 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.370 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.574 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.342 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.721 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.514 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.532 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.557 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.335 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.397 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.495 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.056 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.032 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.008 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.030 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.956 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.664 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.715 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.655 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.592 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.656 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.478 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.486 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.480 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.489 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.419 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.367 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.420 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.363 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.355 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.475 seconds
# ('Chosen c value: ', 1000000000000.0)
# ('Classification accuracy: ', 0.817)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.601 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.632 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.586 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.431 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.508 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.676 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.662 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.696 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.548 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.491 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.553 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.653 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.581 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.526 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.481 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.540 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.499 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.646 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.415 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.284 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.399 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.453 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.514 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.575 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.448 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.666 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.520 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.564 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.967 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.053 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.966 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.107 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.038 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.683 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.600 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.658 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.670 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.682 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.480 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.507 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.495 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.486 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.496 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.355 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.382 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.364 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.376 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.362 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.478 seconds
# ('Chosen c value: ', 1000000000000.0)
# ('Classification accuracy: ', 0.8220000000000001)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.840 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.082 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.590 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.734 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.519 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.690 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.496 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.617 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.589 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.743 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.613 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.693 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.431 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.726 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.652 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.490 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.633 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.600 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.506 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.528 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.324 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.586 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.464 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.121 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.254 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.156 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.268 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.254 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.239 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.870 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.942 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.925 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.933 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.868 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 0.584 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.688 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.641 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.574 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.584 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.455 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.464 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.464 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.458 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.347 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.343 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.350 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.340 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.353 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.138 seconds
# ('Chosen c value: ', 100000.0)
# ('Classification accuracy: ', 0.826)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.292 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.625 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.286 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.652 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.409 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.671 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.735 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.551 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.421 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.619 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.519 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.622 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.677 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.571 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.266 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.517 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.374 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.264 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.115 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.377 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.139 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.340 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.252 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.379 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.438 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.444 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.396 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.346 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.313 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.057 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.834 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.117 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.959 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.999 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.663 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.652 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.725 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.635 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.650 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.479 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.470 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.482 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.458 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.459 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.409 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.344 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.406 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.343 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.349 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.242 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.829)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.596 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.428 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.692 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.706 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.617 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.793 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.431 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.517 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.422 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.429 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.346 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.535 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.616 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.718 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.577 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.492 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.198 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.316 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.278 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.360 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.236 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.258 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.401 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.162 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.238 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.290 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.320 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.269 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.210 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.925 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.925 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.806 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.941 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.040 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.580 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.573 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.576 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.578 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.707 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.456 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.404 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.457 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.465 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.399 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.349 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.343 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.351 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.343 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.354 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.339 seconds
# ('Chosen c value: ', 100000.0)
# ('Classification accuracy: ', 0.8190000000000002)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.429 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.510 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.309 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.527 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.544 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.312 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.316 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.254 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.387 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.550 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.322 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.290 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.503 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.380 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.491 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.154 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.185 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.195 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.240 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.166 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.233 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.198 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.261 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.188 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.183 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.767 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.165 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.277 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.202 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.119 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.932 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.865 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.038 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.026 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.977 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.577 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.580 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.632 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.690 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.629 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.350 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.455 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.463 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.455 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.469 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.366 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.425 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.402 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.402 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.344 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.688 seconds
# ('Chosen c value: ', 100000000000.0)
# ('Classification accuracy: ', 0.8344999999999999)

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()

# %% [markdown]
# #### RBF Kernel width 0.5 - Scaled #####

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data=np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
kRBF =lambda X1,X2: kC.kernelRBF(X1,X2,0.5)
clf=kC.KernelClassifier(kRBF,withPCA=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.532 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.444 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.442 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.431 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.713 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.456 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.395 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.481 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.481 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.535 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.435 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.712 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.486 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.540 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.368 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.498 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.274 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.263 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.204 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.282 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.199 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.519 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.657 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.143 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.016 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.164 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.868 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.876 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.928 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.925 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.809 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.517 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.574 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.580 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.576 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.593 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.399 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.404 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.404 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.407 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.402 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.345 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.341 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.345 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.344 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.350 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.216 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.825)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.647 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.334 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.296 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.378 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.583 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.690 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.472 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.515 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.373 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.352 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.288 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.420 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.235 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.425 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.460 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.381 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.432 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.290 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.296 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.376 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.303 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.295 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.313 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.238 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.438 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.221 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.329 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.005 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.921 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.922 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.932 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 0.941 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.581 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.589 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.579 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.582 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.634 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.468 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.458 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.464 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.344 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.463 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.345 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.413 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.344 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.350 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.401 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.775 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.8285)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.608 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.453 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.557 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.421 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.477 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.613 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.497 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.584 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.508 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.388 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.652 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.380 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.324 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.378 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.259 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.508 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.263 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.470 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.459 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.682 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.126 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.510 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.274 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.243 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.310 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.256 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.267 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.122 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.170 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.948 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.972 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.932 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.928 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.942 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.645 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.578 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.635 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.583 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.634 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.466 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.464 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.466 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.344 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.467 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.413 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.408 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.407 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.346 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.404 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.8285)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.648 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.336 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.588 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.321 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.546 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.723 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.553 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.670 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.493 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.610 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.804 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.588 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.689 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.458 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.795 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.283 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.506 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.409 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.517 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.318 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.353 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.345 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.423 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.177 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.403 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.257 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.413 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.315 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.304 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.280 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.000 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.811 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.937 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.874 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.948 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.582 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.581 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.580 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.585 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.574 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.408 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.400 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.405 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.407 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.409 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.347 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.354 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.400 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.348 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.347 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.689 seconds
# ('Chosen c value: ', 100000.0)
# ('Classification accuracy: ', 0.828)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.742 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.588 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.769 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.823 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.850 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.937 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.795 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.885 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.019 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.005 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.934 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.010 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.994 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.940 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.801 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.572 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.513 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.678 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.543 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.991 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.414 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.677 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.529 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.549 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.598 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.118 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.746 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.513 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.689 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.012 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.089 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.968 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.965 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.907 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.661 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.596 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.664 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.599 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.600 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.477 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.479 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.482 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.478 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.360 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.420 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.421 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.287 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.8365)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.643 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.633 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.658 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.890 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.969 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.797 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.740 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.812 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.754 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.888 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.802 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.695 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.757 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.839 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.818 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.815 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.555 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.905 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.629 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.973 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.536 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.692 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.707 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.410 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.559 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.200 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 3.205 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.712 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.536 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.520 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.953 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.966 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.899 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.980 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.008 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.615 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.595 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.666 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.594 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.609 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.365 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.417 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.366 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.353 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.360 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.364 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.799 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.8445)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.584 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.719 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.682 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.815 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.664 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.782 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.846 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.994 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.700 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.740 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.652 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.846 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.878 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.927 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.581 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.610 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.617 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.730 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.534 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.827 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.570 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.679 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.420 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.560 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.552 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.749 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.615 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.717 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.482 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.634 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.972 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.859 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.845 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.975 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.837 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.609 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 0.602 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.550 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.540 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.546 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.421 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.423 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.422 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.425 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.421 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.362 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.361 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.746 seconds
# ('Chosen c value: ', 100000.0)
# ('Classification accuracy: ', 0.8310000000000001)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.663 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.904 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.797 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.977 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.755 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.829 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.765 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.962 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.942 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.849 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.753 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.920 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.855 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.830 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.665 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.804 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.670 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.829 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.744 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.594 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.316 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.601 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.456 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.566 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.515 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.561 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.531 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.639 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.458 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.643 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.966 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.906 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.965 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.162 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.956 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.678 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.663 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.607 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.660 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.607 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.481 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.487 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.486 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.485 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.479 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.425 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.433 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.429 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.424 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.363 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.632 seconds
# ('Chosen c value: ', 100000000000.0)
# ('Classification accuracy: ', 0.8390000000000001)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.563 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.812 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.557 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.511 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.677 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.567 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.553 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.636 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.519 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.874 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.886 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.823 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.770 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.882 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.930 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.647 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.818 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.583 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.721 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.537 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.585 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.463 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.425 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.734 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.383 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.610 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.317 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.492 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.391 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.939 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.961 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.826 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.904 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.830 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.595 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.595 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.600 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.587 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.600 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.411 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.475 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.471 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.478 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.411 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.355 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.354 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.356 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.854 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.841)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.552 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.572 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.859 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.721 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.506 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.375 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.602 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.913 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.416 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.579 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.929 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.663 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.882 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.508 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.476 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.455 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.512 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.509 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.620 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.457 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.383 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.315 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.421 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.177 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.413 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.190 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.322 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.229 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.385 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.875 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.892 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.929 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.885 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.874 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.582 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.573 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.586 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.577 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.586 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.408 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.406 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.409 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.411 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.408 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.349 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.349 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.351 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.347 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.355 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.466 seconds
# ('Chosen c value: ', 1000000000000.0)
# ('Classification accuracy: ', 0.8394999999999999)

# %%
plt.clf()
plt.plot(mu_values,true_probabilities,'r*')
plt.plot(mu_values,probabilities,'b*')
plt.show()

# %% [markdown]
# #### RBF Kernel width 0.7 - Scaled #########

# %%
############################################# Algorithm1 ####################################################################
#Disable print statement -- The estimate Probabilities function prints a lot of info.
#sys.stdout = open(os.devnull, 'w')

#Observed data
observed_data=np.array([[0]])
#observed_data=np.random.normal(2.3,3,(1,1))

#Probability of mean.(Uniform prior -20,20)
prior=1/40

#Number of samples to be created by each generator for classification.
n_samples=1000

#Calculate posterior for mu_values 
mu_values=np.linspace(-2*3+ observed_data[0,0],2*3+ observed_data[0,0] ,10)

#Uses linear kernel by default -can specify custom kernel.
kRBF =lambda X1,X2: kC.kernelRBF(X1,X2,0.7)
clf=kC.KernelClassifier(kRBF,withPCA=False)
probabilities =estimateProbabilities(observed_data, prior, mu_values, generator_marginal, generator_thetaGiven, n_samples,clf)

#Enable print statement.
#sys.stdout = sys.__stdout__
plt.figure()
import numpy as np
import matplotlib.mlab as mlab
import math

sigma=3
a_0= lambda mu: -(mu*mu)/(2*sigma*sigma)-np.log(np.sqrt(2*np.pi)*sigma)-np.log(norm.cdf((20-mu)/sigma)-norm.cdf((-20-mu)/sigma))
a_1= lambda mu: mu/(sigma*sigma)
a_2= lambda mu: -1/(2*sigma*sigma)


true_probabilities= np.zeros(10)
i=0
for mu in mu_values:
    true_probabilities[i] = np.exp(a_0(mu)+a_1(mu)*observed_data+a_2(mu)*np.power(observed_data,2))
    i=i+1 

plt.clf()
plt.plot(mu_values,true_probabilities,'r-')
plt.plot(mu_values,probabilities,'b-')
plt.show()
# Out:
# ('-----------CALCULATING Theta VALUE : ', -6.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.265 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.116 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.250 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.183 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.361 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.458 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.308 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.362 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.435 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.309 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.436 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.276 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.313 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.326 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.152 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.124 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.445 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.009 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.212 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.936 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.087 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.047 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.098 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.142 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.045 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.004 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.212 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.024 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.141 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.783 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.911 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.788 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.741 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.730 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.503 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.564 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.568 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.558 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.567 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.358 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.426 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.339 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.340 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.335 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.342 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.337 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.338 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.337 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.341 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.743 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.8185)
# ('-----------CALCULATING Theta VALUE : ', -4.666666666666667, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.192 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.304 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.128 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.432 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.142 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.396 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.349 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.452 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.445 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.250 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.187 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.222 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.235 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.326 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.170 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.309 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.484 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.183 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.312 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.965 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.010 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.110 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.116 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.301 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.074 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.931 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.959 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.059 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.176 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.709 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.730 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.665 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.776 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 0.715 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.551 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.494 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.491 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.506 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.386 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.332 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.384 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.386 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.385 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.335 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.327 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.336 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.132 seconds
# ('Chosen c value: ', 10.0)
# ('Classification accuracy: ', 0.8105)
# ('-----------CALCULATING Theta VALUE : ', -3.3333333333333335, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.267 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.426 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.160 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.257 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.156 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.209 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.316 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.106 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.127 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.379 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.120 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.097 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.982 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.221 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.015 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.939 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.035 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.009 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.218 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.295 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.060 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.134 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.036 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.948 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.232 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.919 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.780 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.728 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.998 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.962 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.821 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.661 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.869 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.712 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.765 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.494 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.543 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.495 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.495 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.441 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.334 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.380 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.380 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.333 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.089 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.8200000000000001)
# ('-----------CALCULATING Theta VALUE : ', -2.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.225 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.353 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.187 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.181 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.241 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.214 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.101 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.335 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.063 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.416 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.142 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.242 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.156 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.214 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.921 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.932 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.038 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.001 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.103 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.102 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.057 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.019 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.975 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.051 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.073 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.876 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.851 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.925 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.776 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.074 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.861 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.769 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.700 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.926 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.861 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.553 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.549 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.548 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.542 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.556 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.431 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.324 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.332 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.327 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.388 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.327 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.720 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.8365)
# ('-----------CALCULATING Theta VALUE : ', -0.66666666666666696, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.269 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.104 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.152 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.969 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.242 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.314 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.186 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.139 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.071 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.335 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.491 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.120 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.010 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.211 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.087 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.168 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.083 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.012 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.159 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.772 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.122 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.954 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.890 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.080 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.056 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.852 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.910 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.010 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.918 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.648 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.774 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.764 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.722 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.767 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.555 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.549 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.551 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.552 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.555 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.381 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.335 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.384 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.390 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.385 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.326 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.330 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 7.988 seconds
# ('Chosen c value: ', 1000.0)
# ('Classification accuracy: ', 0.8315000000000001)
# ('-----------CALCULATING Theta VALUE : ', 0.66666666666666607, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.105 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.274 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.079 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.170 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.032 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.197 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.101 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.195 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.225 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.063 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.956 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.127 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.054 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.429 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.986 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.045 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.147 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.148 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.797 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.978 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.891 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.984 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.095 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.962 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.044 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.519 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.985 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.922 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.801 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.801 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.757 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.765 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.640 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.716 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.814 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.549 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.538 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.543 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.540 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.544 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.377 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.384 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.378 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.326 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.323 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.323 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.332 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.227 seconds
# ('Chosen c value: ', 100000.0)
# ('Classification accuracy: ', 0.8370000000000001)
# ('-----------CALCULATING Theta VALUE : ', 2.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.097 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.143 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.216 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.370 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.195 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.147 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.270 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.180 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.122 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.141 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.139 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.514 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.164 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.265 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.081 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.181 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.119 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.066 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.082 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.064 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.914 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.120 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.962 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.109 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.203 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.180 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.956 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.930 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.886 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.072 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.900 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.902 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.943 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.855 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.893 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
# COMPLETED. Running Time: 0.548 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.551 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.577 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.542 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.546 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.404 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.333 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.403 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.351 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.325 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.330 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.155 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.835)
# ('-----------CALCULATING Theta VALUE : ', 3.3333333333333321, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.231 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.310 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.434 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.238 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.411 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.348 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.311 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.392 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.285 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.238 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.081 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.145 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.234 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.137 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.352 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.079 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.110 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.970 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.032 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.964 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.278 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.044 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.893 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.074 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.019 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.070 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.988 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.816 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.129 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.049 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.658 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.827 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.933 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.823 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.834 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.543 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.555 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.597 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.603 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.545 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.440 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.334 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.436 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.380 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.332 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.387 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.329 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 8.444 seconds
# ('Chosen c value: ', 1000.0)
# ('Classification accuracy: ', 0.8435)
# ('-----------CALCULATING Theta VALUE : ', 4.6666666666666661, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.339 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.189 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.186 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.149 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.591 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.169 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.198 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.200 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.140 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.311 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.420 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.289 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.357 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.162 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.201 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.042 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.121 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.217 seconds
# Training kernel logistic regression model...
# COMPLETED. Running Time: 6.149 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.219 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.359 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.178 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.155 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.912 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.117 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.896 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.967 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.897 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.139 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 5.934 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.730 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.728 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.778 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.709 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.794 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.559 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.501 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.562 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.504 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.505 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.338 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.393 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.391 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.383 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.390 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.331 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.336 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.332 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.335 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.335 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.746 seconds
# ('Chosen c value: ', 10000000000.0)
# ('Classification accuracy: ', 0.845)
# ('-----------CALCULATING Theta VALUE : ', 6.0, ' -------------------')
# ('Training for c value: ', 1.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.240 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.450 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.251 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.407 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.383 seconds
# ('Training for c value: ', 10.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.443 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.457 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.509 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.341 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.345 seconds
# ('Training for c value: ', 1000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.394 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.484 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.311 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.231 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.230 seconds
# ('Training for c value: ', 100000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.334 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.258 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.111 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.354 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.372 seconds
# ('Training for c value: ', 1000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.328 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.064 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.180 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.091 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.253 seconds
# ('Training for c value: ', 10000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 2.090 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.256 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.065 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.020 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 6.043 seconds
# ('Training for c value: ', 1000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.850 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.783 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.669 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.726 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.730 seconds
# ('Training for c value: ', 10000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.502 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.503 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.504 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.556 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.527 seconds
# ('Training for c value: ', 100000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.414 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.398 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.392 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.332 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.391 seconds
# ('Training for c value: ', 1000000000000.0)
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.340 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.333 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.336 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.336 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 0.336 seconds
# Training kernel logistic regression model...
#
# COMPLETED. Running Time: 1.113 seconds
# ('Chosen c value: ', 1000000000.0)
# ('Classification accuracy: ', 0.8455)
