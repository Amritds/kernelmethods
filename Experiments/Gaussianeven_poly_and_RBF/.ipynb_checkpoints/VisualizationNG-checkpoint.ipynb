# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from Utilities.ExpModels import  GaussianModel

model = GaussianModel(3,-20,20, 432)

# %%
prob2 =np.load('ObsPolyprob_deg2.npy')
prob4 =np.load('ObsPolyprob_deg4.npy') 
prob6 =np.load('ObsPolyprob_deg6.npy') 

prob1 =np.load('ObsPolyprob_deg1.npy')
prob3 =np.load('ObsPolyprob_deg3.npy') 
prob5 =np.load('ObsPolyprob_deg5.npy')

# %%
obsData = np.load('ObservedData.npy')
np.amin(obsData)
# Out:
# -6.9206067877708719

# %%
kD_POLY1 =np.load('KL_POLY_degree1.npy')
kD_POLY2 =np.load('KL_POLY_degree2.npy')
kD_POLY3 =np.load('KL_POLY_degree3.npy')
kD_POLY4 =np.load('KL_POLY_degree4.npy')
kD_POLY5 =np.load('KL_POLY_degree5.npy')
kD_POLY6 =np.load('KL_POLY_degree6.npy')

# %%
plt.clf()
fig =plt.figure()
ax = fig.add_subplot(111)
for i in range(0,10):
    plt.plot([1,2,3,4,5,6],[-kD_POLY1[i],-kD_POLY2[i],-kD_POLY3[i],-kD_POLY4[i],-kD_POLY5[i],-kD_POLY6[i]])
ax.set_xlabel('choice of degree')
ax.set_ylabel('sKL divergence from true posterior')
plt.legend()
plt.show()
fig.savefig('KL_Div.pdf')

# %%
(gen,obsdata) = obsData

# %%
classifiers_test_scores.shape
#POLY
#RBF
#S_POLY
#S_RBF
# Out:
# (4, 100)

# %%
obsdata[2]
# Out:
# array([ 0.87114289])

# %%
print(kD_POLY2[0])
print(kD_POLY4[0])
# Out:
# 0.0131683899592
# 0.0547944578276

# %%
plt.clf()
fig =plt.figure()
ax =fig.add_subplot(111)
#density = gaussian_kde(delta)
#xs = np.linspace(-2,2,50)
#ax.plot(xs,density(xs))
ax.hist(kD_SRBF)
#ax.plot(np.linspace(-6,6,100),classifiers_test_scores[0],label ='POLY')
#ax.plot(np.linspace(-6,6,100),classifiers_test_scores[1],label='RBF')


ax.vlines(0,0,1)
ax.set_xlabel('Delta kl divergence RBF, POLY kernels')
ax.set_ylabel('Frequency')
plt.legend()
plt.show()
fig.savefig('POLY_kD.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8baf00cb8e2d> in <module>()
#       5 #xs = np.linspace(-2,2,50)
#       6 #ax.plot(xs,density(xs))
# ----> 7 ax.hist(kD_SRBF)
#       8 #ax.plot(np.linspace(-6,6,100),classifiers_test_scores[0],label ='POLY')
#       9 #ax.plot(np.linspace(-6,6,100),classifiers_test_scores[1],label='RBF')
#
# NameError: name 'kD_SRBF' is not defined

# %%
#Observation:
#Standardization has no effect for poly, exact same kl divergence approximated.
#Standardization for rbf very slightly worse kl divergence
#Poly wins.
#Best performer: Poly degree 2 kernel
#Plot the avg kl divergence

# %%
np.mean(kD_POLY)
# Out:
# 0.074111072969183345

# %%
A=(kD_POLY -np.mean(kD_POLY))

# %%
np.argmin(A)
# Out:
# 2

# %%
(generatingParameters,obsData) = np.load('ObservedData.npy')
obsData.shape
# Out:
# (100, 1)

# %%
obsData =np.abs(obsData)

# %%
np.argmin(obsData)
# Out:
# 69

# %%
obsData[69]
# Out:
# array([ 0.13966503])

# %%
kD_POLY[69]
# Out:
# 0.010901286732881772

# %%
kD_RBF[69]
# Out:
# 0.0084089251546434433

# %%
# StandRBF vs RBF 
# RBF vs POLY 
# SHOW accuracies for RBF and poly are nearly identical across mu values.

#Hist POLY 
#True posterior plots poly,rbf at obs data = 0

# %%
observedData = 0
plt.clf()
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(1,1,1)
line1, = ax.plot(np.linspace(-6,6,100),model.truePosterior(np.linspace(-6,6,100),observedData),'g-')
line2, = ax.plot(np.linspace(-6,6,100),prob3[0],'b-')
ax.legend((line1,line2),('true posterior','estimated posterior'))
ax.set_xlabel('mu value')
ax.set_ylabel('probability')
plt.show()
fig.savefig('Deg1post.pdf')

# %%
with open('Standardized_POLY_parametersAndRegScales.pickle', 'rb') as f:
     choice  = pickle.load(f)

# %%
np.argmin(observedData)
# Out:
# 0

# %%
from pathlib import Path
file = Path('./RBF_klDivergence.npy')
if(file.is_file()):
    print('True')
else:
    print('False')
# Out:
# True

# %%
import numpy as np
(gp,obs) = np.load('ObservedData.npy')

# %%
np.vstack([0,obs])
# Out:
# array([[ 0.        ],
#        [ 2.4050899 ],
#        [-2.2935863 ],
#        [ 0.87114289],
#        [ 0.39782116],
#        [ 0.65684598],
#        [-2.64083487],
#        [-0.68885963],
#        [-0.75313348],
#        [-1.33007611],
#        [-0.55417064],
#        [-5.10993481],
#        [-1.51694041],
#        [ 1.79751017],
#        [-0.7205219 ],
#        [ 5.43076535],
#        [ 9.52508802],
#        [ 0.20334999],
#        [ 0.41592435],
#        [-0.26066827],
#        [-0.27676361],
#        [ 0.8005594 ],
#        [-2.67746446],
#        [ 6.94474018],
#        [ 2.8957666 ],
#        [-1.79295478],
#        [ 2.04817148],
#        [ 0.72399357],
#        [ 0.66257636],
#        [ 4.64401014],
#        [-1.67369425],
#        [ 2.29515005],
#        [-1.91490241],
#        [-0.66416007],
#        [ 2.41359353],
#        [-1.44644111],
#        [ 0.62482628],
#        [ 3.65095659],
#        [ 1.1590936 ],
#        [ 1.79092774],
#        [-0.64368875],
#        [-0.87223567],
#        [-1.10500887],
#        [ 4.20273681],
#        [ 0.26020339],
#        [-2.19134069],
#        [ 5.84372395],
#        [-5.43677687],
#        [-0.12274762],
#        [ 2.26430397],
#        [-1.74016511],
#        [-3.80764613],
#        [ 2.06770174],
#        [ 0.74254618],
#        [-0.54668354],
#        [-4.36076387],
#        [ 2.99920156],
#        [ 1.00107591],
#        [ 4.37645603],
#        [ 0.18670202],
#        [-0.79942902],
#        [ 1.13953626],
#        [ 3.70215184],
#        [ 3.63496005],
#        [ 1.74236296],
#        [ 1.69670132],
#        [ 1.9340208 ],
#        [-0.03824971],
#        [-0.5661751 ],
#        [ 2.8106264 ],
#        [ 6.71468583],
#        [ 5.67377257],
#        [-2.85165293],
#        [-1.71355829],
#        [ 3.64112982],
#        [ 1.4339785 ],
#        [-3.23424947],
#        [-0.44547837],
#        [ 1.90413514],
#        [-3.17936786],
#        [-3.06373459],
#        [-0.02979688],
#        [ 2.14732816],
#        [ 1.30735692],
#        [-4.09532549],
#        [ 0.59488972],
#        [-0.82658747],
#        [ 2.13430534],
#        [-6.92060679],
#        [-1.96534814],
#        [-1.91178003],
#        [ 0.57914993],
#        [-1.85197139],
#        [ 4.03659012],
#        [ 4.4319663 ],
#        [ 0.70803405],
#        [-0.76137323],
#        [-0.93058168],
#        [ 4.5100564 ],
#        [-1.6046104 ],
#        [-3.17054549]])
